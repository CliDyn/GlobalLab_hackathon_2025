# %% [markdown]
# # ICCP data

# %% [markdown]
# All data are located in this folder: `/work/ab0995/ICCP_AWI_hackthon_2025/`
#
# Below are catalogs, but some data are corrupted or still downloading, and not part of the catalogs. We eill update it during the hackathon.

# %%
import xarray as xr
import numpy as np
import intake
# Out:
# /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
gl_cat=intake.open_catalog("https://raw.githubusercontent.com/CliDyn/GlobalLab_hackathon_2025/refs/heads/main/catalog/main.yaml")

organisation="ICCP" # ICCP, AWI
expid = 'TCO95L91-CORE2-ctl1950d'  # 'TCo319-DART-ctl1950d-gibbs-charn', 
                                   # 'TCo319-DART-hi1950d-gibbs-charn', 
                                   # 'TCo319-DART-ssp585d-gibbs-charn', 
                                   # 'TCO95L91-CORE2-ctl1950d',
                                   # 'TCO95L91-CORE2-ssp585d'
                                   # 'TCo1279-DART-1950C'
                                   # 'TCo1279-DART-2080C'

realm='atmos'  # 'ocean' , 'atmos'
gridspec = 'remap' # 'native', 'remap'

cat_data=gl_cat[organisation][expid][realm][gridspec]
print(list(cat_data))
# Out:
# ['atmos_6h']

# %%
data = cat_data['atmos_6h'].to_dask()

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:          (time_counter: 29220, lat: 192, lon: 400,
#                       pressure_levels: 19)
# Coordinates:
#   * lat              (lat) float32 -89.53 -88.59 -87.66 ... 87.66 88.59 89.53
#   * lon              (lon) float32 0.45 1.35 2.25 3.15 ... 357.8 358.6 359.5
#   * pressure_levels  (pressure_levels) float32 1e+05 9.25e+04 ... 500.0 100.0
#   * time_counter     (time_counter) datetime64[ns] 1950-01-01T06:00:00 ... 19...
# Data variables:
#     10u              (time_counter, lat, lon) float32 dask.array<chunksize=(1, 192, 400), meta=np.ndarray>
#     10v              (time_counter, lat, lon) float32 dask.array<chunksize=(1, 192, 400), meta=np.ndarray>
#     2t               (time_counter, lat, lon) float32 dask.array<chunksize=(1, 192, 400), meta=np.ndarray>
#     hcc              (time_counter, lat, lon) float32 dask.array<chunksize=(1, 192, 400), meta=np.ndarray>
#     lcc              (time_counter, lat, lon) float32 dask.array<chunksize=(1, 192, 400), meta=np.ndarray>
#     mcc              (time_counter, lat, lon) float32 dask.array<chunksize=(1, 192, 400), meta=np.ndarray>
#     tcc              (time_counter, lat, lon) float32 dask.array<chunksize=(1, 192, 400), meta=np.ndarray>
#     w                (time_counter, pressure_levels, lat, lon) float32 dask.array<chunksize=(1, 19, 192, 400), meta=np.ndarray>
# Attributes:
#     name:         atm_remapped_6h_tcc_6h
#     description:  ECE4/OIFS 6hourly surface fields
#     title:        ECE4/OIFS 6hourly surface fields
#     Conventions:  CF-1.6
#     timeStamp:    2025-Jul-21 09:22:59 GMT
#     uuid:         92a2c655-87a3-4f11-9d9a-afeb56beac6d

# %% [markdown]
# ## For some of the variables we have individual catalog records, so you can do:

# %%
gl_cat=intake.open_catalog("https://raw.githubusercontent.com/CliDyn/GlobalLab_hackathon_2025/refs/heads/main/catalog/main.yaml")
# gl_cat=intake.open_catalog("/home/a/a270088/PYTHON/GlobalLab/catalog/main.yaml")

organisation="ICCP" # ICCP, AWI
expid = 'TCO95L91-CORE2-ctl1950d'  # 'TCo319-DART-ctl1950d-gibbs-charn', 
                                   # 'TCo319-DART-hi1950d-gibbs-charn', 
                                   # 'TCo319-DART-ssp585d-gibbs-charn', 
                                   # 'TCO95L91-CORE2-ctl1950d',
                                   # 'TCO95L91-CORE2-ssp585d'

realm='ocean'  # 'ocean' , 'atmos'
gridspec = 'native' # 'native', 'remap'

print(list(gl_cat[organisation]['TCo1279-DART-1950C']['ocean']['native']))
# print(list(cat_data))
# Out:
# ['ocean_monthly', 'ocean_daily_2d', 'ocean_daily_3d', 'ocean_daily_temp', 'ocean_daily_salt', 'ocean_daily_u', 'ocean_daily_v', 'ocean_daily_w']

# %%
cat = gl_cat[organisation]['TCo1279-DART-1950C']['ocean']['native']

ds_temp = cat['ocean_daily_temp'].to_dask()
ds_salt = cat['ocean_daily_salt'].to_dask()
ds_u = cat['ocean_daily_u'].to_dask()
ds_v = cat['ocean_daily_v'].to_dask()

data = xr.merge([ds_temp, ds_salt, ds_u, ds_v])

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:   (nz1: 31, time: 7305, nod2: 3160340, elem: 6262485)
# Coordinates:
#   * nz1       (nz1) float64 2.5 7.5 15.0 25.0 35.0 ... 415.0 445.0 475.0 505.0
# Dimensions without coordinates: time, nod2, elem
# Data variables:
#     temp1-31  (time, nod2, nz1) float32 dask.array<chunksize=(1, 316034, 2), meta=np.ndarray>
#     salt1-31  (time, nod2, nz1) float32 dask.array<chunksize=(1, 316034, 2), meta=np.ndarray>
#     u1-31     (time, elem, nz1) float32 dask.array<chunksize=(1, 447321, 1), meta=np.ndarray>
#     v1-31     (time, elem, nz1) float32 dask.array<chunksize=(1, 447321, 1), meta=np.ndarray>
# Attributes: (12/19)
#     FESOM_model:                         FESOM2
#     FESOM_website:                       fesom.de
#     FESOM_git_SHA:                       unknown
#     FESOM_MeshPath:                      /h3/data/rndg/rnd064/AWICM3/input/fe...
#     FESOM_mesh_representative_checksum:  6c981535dc5a7a40cdd900a071c1a744
#     FESOM_ClimateDataPath:               /h3/data/rndg/rnd064/AWICM3/input//f...
#     ...                                  ...
#     FESOM_include_fleapyear:             -1
#     FESOM_use_floatice:                  0
#     FESOM_whichEVP:                      2
#     FESOM_evp_rheol_steps:               120
#     FESOM_visc_option:                   7
#     FESOM_w_split:                       -1

# %% [markdown]
# ## Display current state of the catalog

# %%
import intake
import xarray as xr
import pandas as pd
from tqdm.auto import tqdm
import textwrap

catalog_url = "https://raw.githubusercontent.com/CliDyn/GlobalLab_hackathon_2025/refs/heads/main/catalog/main.yaml"
# catalog_url = "../catalog/main.yaml"
model = "ifs-fesom2-sr"
version = "v20240304"

expids   = [
    'TCo319-DART-ctl1950d-gibbs-charn', 
    'TCo319-DART-hi1950d-gibbs-charn',
    'TCo319-DART-ssp585d-gibbs-charn',
    'TCO95L91-CORE2-ctl1950d',
    'TCO95L91-CORE2-ssp585d',
    'TCo1279-DART-1950C',
    'TCo1279-DART-2080C'
]
realms    = ["ocean", "atmos"]
gridspecs = ["native", "remap"]

# Width of the variables column for wrapping
VARIABLES_COL_WIDTH = 60


def print_table_multiline(results):
    """Print a table where 'variables' can span multiple lines, keeping columns aligned."""
    headers = ["expid", "realm", "gridspec", "dataset",
               "time_coord", "first_year", "last_year", "variables"]

    # Compute column widths for all columns except 'variables'
    col_widths = {}
    for h in headers:
        if h == "variables":
            continue
        max_len = max(len(str(row[h])) for row in results)
        col_widths[h] = max(max_len, len(h))

    # Set variables column width explicitly (for wrapping)
    col_widths["variables"] = max(len("variables"), VARIABLES_COL_WIDTH)

    def format_line(row_values):
        return " | ".join(
            f"{str(row_values[h]):<{col_widths[h]}}"
            for h in headers
        )

    # Header
    header_line = format_line({h: h for h in headers})
    print(header_line)
    print("-" * len(header_line))

    # Rows
    for r in results:
        var_text = str(r["variables"])
        wrapped_vars = textwrap.wrap(
            var_text,
            width=col_widths["variables"],
            break_long_words=False,
            break_on_hyphens=False
        ) or [""]

        # First line: all columns
        first_line_values = {
            "expid":      r["expid"],
            "realm":      r["realm"],
            "gridspec":   r["gridspec"],
            "dataset":    r["dataset"],
            "time_coord": r["time_coord"],
            "first_year": r["first_year"],
            "last_year":  r["last_year"],
            "variables":  wrapped_vars[0],
        }
        print(format_line(first_line_values))

        # Continuation lines: only variables
        for cont in wrapped_vars[1:]:
            cont_values = {
                "expid":      "",
                "realm":      "",
                "gridspec":   "",
                "dataset":    "",
                "time_coord": "",
                "first_year": "",
                "last_year":  "",
                "variables":  cont,
            }
            print(format_line(cont_values))


def main():
    eerie_cat = intake.open_catalog(catalog_url)
    base_cat = eerie_cat["ICCP"]

    results = []

    # --------------------------------------------------------------
    # First pass: collect all dataset tasks so tqdm knows total count
    # --------------------------------------------------------------
    tasks = []
    for expid in expids:
        for realm in realms:
            for gridspec in gridspecs:
                try:
                    exp_node   = base_cat[expid]
                    realm_node = exp_node[realm]
                    grid_node  = realm_node[gridspec]
                except KeyError:
                    continue  # silently skip combinations not present

                dataset_names = list(grid_node)
                if not dataset_names:
                    continue

                for ds_name in dataset_names:
                    tasks.append((expid, realm, gridspec, ds_name))

    if not tasks:
        print("No datasets found for the given combinations.")
        return

    # --------------------------------------------------------------
    # Second pass: process each dataset with a progress bar
    # --------------------------------------------------------------
    for expid, realm, gridspec, ds_name in tqdm(tasks, desc="Processing datasets"):
        try:
            ds = base_cat[expid][realm][gridspec][ds_name].to_dask()

            # Support both "time" and "time_counter"
            time_candidates = ["time", "time_counter"]
            time_name = None
            for candidate in time_candidates:
                if candidate in ds.coords or candidate in ds.dims:
                    time_name = candidate
                    break

            if time_name is None:
                continue

            time = ds[time_name]
            dim_name = time.dims[0] if time.dims else time_name

            first_time = pd.to_datetime(time.isel({dim_name: 0}).compute().values)
            last_time  = pd.to_datetime(time.isel({dim_name: -1}).compute().values)

            first_year = int(first_time.year)
            last_year  = int(last_time.year)

            var_names = sorted(list(ds.data_vars))
            variables = ", ".join(var_names)

            results.append(
                dict(
                    expid=expid,
                    realm=realm,
                    gridspec=gridspec,
                    dataset=ds_name,
                    time_coord=time_name,
                    first_year=first_year,
                    last_year=last_year,
                    variables=variables,
                )
            )

        except Exception:
            # Skip problematic datasets silently; only final table is shown
            continue

    if results:
        results_sorted = sorted(
            results,
            key=lambda r: (r["expid"], r["realm"], r["gridspec"], r["dataset"])
        )
        print("\n==================== SUMMARY ====================\n")
        print_table_multiline(results_sorted)
    else:
        print("No time information found for any combination.")


if __name__ == "__main__":
    main()
# Out:
# Processing datasets:   0%|          | 0/23 [00:00<?, ?it/s]
# ==================== SUMMARY ====================
#
# expid                            | realm | gridspec | dataset         | time_coord   | first_year | last_year | variables
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# TCO95L91-CORE2-ctl1950d          | atmos | remap    | atmos_6h        | time_counter | 1950       | 1970      | 10u, 10v, 2t, hcc, lcc, mcc, tcc, w
# TCO95L91-CORE2-ctl1950d          | ocean | native   | ocean_daily     | time         | 1950       | 1969      | a_ice, m_ice, salt1-31, temp1-31, u1-31, uice, v1-31, vice,
#                                  |       |          |                 |              |            |           | w1-31
# TCO95L91-CORE2-ctl1950d          | ocean | native   | ocean_monthly   | time         | 1950       | 1969      | MLD2, fh, tx_sur, ty_sur
# TCO95L91-CORE2-ssp585d           | atmos | remap    | atmos_6h        | time_counter | 2080       | 2100      | 10u, 10v, 2t, hcc, lcc, mcc, tcc, w
# TCO95L91-CORE2-ssp585d           | atmos | remap    | atmos_daily     | time_counter | 2080       | 2099      | cp, lsp
# TCO95L91-CORE2-ssp585d           | ocean | native   | ocean_daily     | time         | 2080       | 2099      | a_ice, m_ice, salt1-31, temp1-31, u1-31, uice, v1-31, vice
# TCO95L91-CORE2-ssp585d           | ocean | native   | ocean_monthly   | time         | 2080       | 2099      | MLD2, fh, tx_sur, ty_sur
# TCo1279-DART-1950C               | atmos | native   | atmos_3h        | time_counter | 1950       | 1970      | 10u, 10v, 2t, bounds_lat, bounds_lon, cp, hcc, lat_bnds,
#                                  |       |          |                 |              |            |           | lcc, lon_bnds, lsp, mcc, time_counter_bnds, w
# TCo1279-DART-1950C               | atmos | remap    | atmos_monthly   | time_counter | 1950       | 1969      | ssrc, ssrd, strc, strd, time_counter_bnds, tsrc, ttr, ttrc
# TCo1279-DART-1950C               | ocean | native   | ocean_daily_2d  | time         | 1950       | 1969      | a_ice, m_ice, uice, vice
# TCo1279-DART-1950C               | ocean | native   | ocean_monthly   | time         | 1950       | 1969      | MLD2, fh, tx_sur, ty_sur
# TCo1279-DART-2080C               | atmos | native   | atmos_3h        | time_counter | 2080       | 2093      | 10u, bounds_lat, bounds_lon, cp, hcc, lat_bnds, lcc,
#                                  |       |          |                 |              |            |           | lon_bnds, lsp, mcc, tcc, time_counter_bnds, w
# TCo1279-DART-2080C               | atmos | remap    | atmos_monthly   | time_counter | 2080       | 2092      | ssrc, time_counter_bnds, ttr
# TCo1279-DART-2080C               | ocean | native   | ocean_daily_2d  | time         | 2080       | 2092      | a_ice, m_ice, uice, vice
# TCo1279-DART-2080C               | ocean | native   | ocean_monthly   | time         | 2080       | 2092      | MLD2, fh, tx_sur, ty_sur
# TCo319-DART-ctl1950d-gibbs-charn | atmos | remap    | atmos_6h        | time_counter | 1950       | 1970      | 10u, 10v, 2t, hcc, lcc, mcc, tcc, time_counter_bnds, w
# TCo319-DART-ctl1950d-gibbs-charn | atmos | remap    | atmos_daily     | time_counter | 1950       | 1969      | cp, lsp
# TCo319-DART-hi1950d-gibbs-charn  | atmos | remap    | atmos_daily     | time         | 1980       | 2014      | ivt_u, ivt_v
# TCo319-DART-hi1950d-gibbs-charn  | atmos | remap    | atmos_monthly   | time_counter | 1980       | 2014      | 10u, 10v, 2t, cp, lsp
# TCo319-DART-ssp585d-gibbs-charn  | atmos | remap    | atmos_6h        | time_counter | 2080       | 2100      | 10u, 10v, 2t, hcc, lcc, mcc, tcc
# TCo319-DART-ssp585d-gibbs-charn  | atmos | remap    | atmos_daily     | time_counter | 2080       | 2099      | cp, lsp
# TCo319-DART-ssp585d-gibbs-charn  | atmos | remap    | atmos_daily_ivt | time         | 2015       | 2100      | ivt_u, ivt_v
# TCo319-DART-ssp585d-gibbs-charn  | atmos | remap    | atmos_monthly   | time_counter | 2015       | 2099      | 10u, 10v, 2t, cp, lsp
